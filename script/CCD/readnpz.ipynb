# %%
import numpy as np

# %%
data=np.load(r"F:\data\CarCrash\vgg16_features\negative\000001.npz",allow_pickle=True)
# data.shape()
print(data)
# Out:
# NpzFile 'F:\\data\\CarCrash\\vgg16_features\\negative\\000001.npz' with keys: data, det, labels, ID
