# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ==============================================================================
# 单元格 1：环境设置与API Key配置
# ==============================================================================
print("正在安装/升级Google AI Generative Language库...")
# !pip install -q --upgrade google-generativeai

print("\n正在配置API Key...")
import google.generativeai as genai
from google.colab import userdata

try:
    # 从Colab密文中安全地获取API Key
    api_key = userdata.get('GEMINI_API_KEY')
    if not api_key:
        raise userdata.SecretNotFoundError("API Key is empty or not found in secrets.")

    # 使用 configure 方法配置 API Key
    genai.configure(api_key=api_key)

    print("API Key配置成功！")

except userdata.SecretNotFoundError:
    print("错误：未在Colab密文中找到名为 'GEMINI_API_KEY' 的密文，或密文为空。请先添加您的API Key。")
except Exception as e:
    print(f"配置时发生错误: {e}")
# Out:
# 正在安装/升级Google AI Generative Language库...
#
# 正在配置API Key...
# API Key配置成功！

# %%
# 获取可用模型列表
models = genai.list_models()
for model in models:
    print(f"模型名称: {model.name}, 支持的任务: {model.supported_generation_methods}")
# Out:
# 模型名称: models/embedding-gecko-001, 支持的任务: ['embedText', 'countTextTokens']
# 模型名称: models/gemini-2.5-flash, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.5-pro, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.0-flash-exp, 支持的任务: ['generateContent', 'countTokens', 'bidiGenerateContent']
# 模型名称: models/gemini-2.0-flash, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.0-flash-001, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.0-flash-exp-image-generation, 支持的任务: ['generateContent', 'countTokens', 'bidiGenerateContent']
# 模型名称: models/gemini-2.0-flash-lite-001, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.0-flash-lite, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.0-flash-lite-preview-02-05, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.0-flash-lite-preview, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-exp-1206, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.5-flash-preview-tts, 支持的任务: ['countTokens', 'generateContent']
# 模型名称: models/gemini-2.5-pro-preview-tts, 支持的任务: ['countTokens', 'generateContent']
# 模型名称: models/gemma-3-1b-it, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/gemma-3-4b-it, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/gemma-3-12b-it, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/gemma-3-27b-it, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/gemma-3n-e4b-it, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/gemma-3n-e2b-it, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/gemini-flash-latest, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-flash-lite-latest, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-pro-latest, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.5-flash-lite, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.5-flash-image-preview, 支持的任务: ['generateContent', 'countTokens', 'batchGenerateContent']
# 模型名称: models/gemini-2.5-flash-image, 支持的任务: ['generateContent', 'countTokens', 'batchGenerateContent']
# 模型名称: models/gemini-2.5-flash-preview-09-2025, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-2.5-flash-lite-preview-09-2025, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-3-pro-preview, 支持的任务: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# 模型名称: models/gemini-3-pro-image-preview, 支持的任务: ['generateContent', 'countTokens', 'batchGenerateContent']
# 模型名称: models/nano-banana-pro-preview, 支持的任务: ['generateContent', 'countTokens', 'batchGenerateContent']
# 模型名称: models/gemini-robotics-er-1.5-preview, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/gemini-2.5-computer-use-preview-10-2025, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/deep-research-pro-preview-12-2025, 支持的任务: ['generateContent', 'countTokens']
# 模型名称: models/embedding-001, 支持的任务: ['embedContent']
# 模型名称: models/text-embedding-004, 支持的任务: ['embedContent']
# 模型名称: models/gemini-embedding-exp-03-07, 支持的任务: ['embedContent', 'countTextTokens', 'countTokens']
# 模型名称: models/gemini-embedding-exp, 支持的任务: ['embedContent', 'countTextTokens', 'countTokens']
# 模型名称: models/gemini-embedding-001, 支持的任务: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']
# 模型名称: models/aqa, 支持的任务: ['generateAnswer']
# 模型名称: models/imagen-4.0-generate-preview-06-06, 支持的任务: ['predict']
# 模型名称: models/imagen-4.0-ultra-generate-preview-06-06, 支持的任务: ['predict']
# 模型名称: models/imagen-4.0-generate-001, 支持的任务: ['predict']
# 模型名称: models/imagen-4.0-ultra-generate-001, 支持的任务: ['predict']
# 模型名称: models/imagen-4.0-fast-generate-001, 支持的任务: ['predict']
# 模型名称: models/veo-2.0-generate-001, 支持的任务: ['predictLongRunning']
# 模型名称: models/veo-3.0-generate-001, 支持的任务: ['predictLongRunning']
# 模型名称: models/veo-3.0-fast-generate-001, 支持的任务: ['predictLongRunning']
# 模型名称: models/veo-3.1-generate-preview, 支持的任务: ['predictLongRunning']
# 模型名称: models/veo-3.1-fast-generate-preview, 支持的任务: ['predictLongRunning']
# 模型名称: models/gemini-2.5-flash-native-audio-latest, 支持的任务: ['countTokens', 'bidiGenerateContent']
# 模型名称: models/gemini-2.5-flash-native-audio-preview-09-2025, 支持的任务: ['countTokens', 'bidiGenerateContent']
# 模型名称: models/gemini-2.5-flash-native-audio-preview-12-2025, 支持的任务: ['countTokens', 'bidiGenerateContent']

# %%
# ==============================================================================
# 单元格 2：项目配置 (Configuration)
# ==============================================================================
import os
import re
import json
import time
from tqdm.notebook import tqdm

class Config:
    # --- 本地路径配置 (请根据您的Google Drive路径修改) ---
    GDRIVE_PROJECT_PATH = "/content/drive/MyDrive/data"
    VIDEO_INPUT_DIR = os.path.join(GDRIVE_PROJECT_PATH, "Crash-1500")
    OUTPUT_DIR = os.path.join(GDRIVE_PROJECT_PATH, "VQA_outputs")
    JSON_OUTPUT_FILE = os.path.join(OUTPUT_DIR, "generated_vqa.json")

    # --- 模型配置 ---
    # Gemini 1.5 Pro的最新模型标识符
    MODEL_ID = "models/gemini-2.5-pro"

    # --- Prompt模板 (保持不变) ---
    SCENE_ANALYSIS_PROMPT = """你是一位顶级的交通事故分析专家。你的任务是基于我提供的视频，对事故场景进行全面的分析。

请严格按照以下的Markdown格式，总结你的分析结果：

### 事故场景综合分析
**1. 环境要素:**
   - **光照与天气:**
   - **道路类型:**
**2. 关键参与者与事发前动态:**
   - **参与者A:**
   - **参与者B:**
**3. 碰撞过程:**
   - **关键行为:**
   - **碰撞描述:**
**4. 事故核心原因推断:**
   - **主要原因:**
""" # 为节省空间省略，请使用之前的Prompt
    VQA_GENERATION_PROMPT = """你是一位顶级的交通安全领域Benchmark出题专家。
你的任务是基于我提供的“视频”和“事故场景综合分析”，为该事故创建一套包含6个问题的视觉问答（VQA）数据。

**输出要求:**
请严格以一个JSON代码块的格式输出，不要有任何其他多余的话。JSON结构必须是包含6个问题对象的列表。语言必须为英文。

**出题详细指令:**
- **维度**: 必须严格按照以下6个维度各出一个问题：`Weather & Light`, `Traffic Environment`, `Road Configuration`, `Accident Type`, `Accident Cause`, `Accident Prevention`.
- **答案设计**: 每个问题必须有4个选项，必须有唯一的正确答案。另外三个选项必须是“高质量的干扰项”——即看似合理但与视频事实不符的描述。
---
**输入信息:**

**1. 事故场景综合分析:**
{scene_analysis_text}

**2. 原始视频:**
[视频内容已作为输入提供]
---
请现在开始生成符合上述所有要求的JSON数据。
""" # 为节省空间省略，请使用之前的Prompt

# 实例化配置
cfg = Config()

# 挂载Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 确保输出目录存在
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
print("配置加载完成，输出目录已确认。")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 配置加载完成，输出目录已确认。

# %%
# ==============================================================================
# 单元格 3：核心功能函数 (Core Helper Functions)
# ==============================================================================

def upload_video_file(local_video_path: str):
    """
    上传本地视频文件到Google AI API，并等待其处理完成。
    返回一个可用于Prompt的文件对象。
    """
    print(f"  正在上传视频: {os.path.basename(local_video_path)}...")
    video_file = genai.upload_file(path=local_video_path)

    # 等待视频处理完成
    while video_file.state.name == "PROCESSING":
        print("  视频正在处理中，请稍候...")
        time.sleep(10)
        video_file = genai.get_file(video_file.name)

    if video_file.state.name == "FAILED":
        raise ValueError("视频文件处理失败。")

    print(f"  视频 '{video_file.display_name}' 上传并处理成功！")
    return video_file

def run_gemini_pipeline_for_video(video_file, model) -> dict:
    """为单个已上传的视频文件执行完整的两阶段生成流程。"""

    # 阶段一：场景分析
    print("    -> 阶段1: 正在进行场景分析...")
    analysis_response = model.generate_content([cfg.SCENE_ANALYSIS_PROMPT, video_file])
    analysis_text = analysis_response.text

    # 阶段二：VQA生成
    print("    -> 阶段2: 正在生成VQA...")
    vqa_prompt = cfg.VQA_GENERATION_PROMPT.format(scene_analysis_text=analysis_text)
    vqa_response = model.generate_content([vqa_prompt, video_file])

    # 从模型输出中解析JSON
    match = re.search(r"```json\s*\n(.*?)\n\s*```", vqa_response.text, re.DOTALL)
    if match:
        try:
            vqa_json = json.loads(match.group(1))
            return {
                "generated_analysis": analysis_text,
                "generated_vqa": vqa_json
            }
        except json.JSONDecodeError as e:
            print(f"    警告: JSON解析失败 - {e}")
            return None
    else:
        print("    警告: 在模型输出中未找到格式化的JSON块。")
        return None

print("核心功能函数定义完成。")
# Out:
# 核心功能函数定义完成。

# %%
# ==============================================================================
# 单元格 4：执行主流程 (Main Execution Loop)
# ==============================================================================

# 初始化模型
model = genai.GenerativeModel(cfg.MODEL_ID)

# 获取所有视频文件列表 (用于存在性检查)
all_video_files_in_dir = set([f for f in os.listdir(cfg.VIDEO_INPUT_DIR) if f.lower().endswith(('.mp4', '.avi', '.mov'))])

# 读取需要处理的视频列表从CSV文件
filtered_videos_path = os.path.join(cfg.GDRIVE_PROJECT_PATH, "filtered_videos.csv")
video_files_to_process_ordered = [] # 存储从CSV读取并过滤后，保持CSV顺序的视频列表
if os.path.exists(filtered_videos_path):
    try:
        import pandas as pd
        df_filtered = pd.read_csv(filtered_videos_path, header=None) # 假设第一列是视频文件名，没有header
        # 格式化第一列的视频名称为6位数字，并确保读取的视频文件名在实际的视频目录中存在
        video_files_from_csv = [f"{int(x):06d}.mp4" for x in df_filtered.iloc[:, 0].tolist()]
        # 仅保留在实际视频目录中存在的视频，并保持CSV中的顺序
        video_files_to_process_ordered = [f for f in video_files_from_csv if f in all_video_files_in_dir]

        print(f"从 {filtered_videos_path} 读取到 {len(video_files_from_csv)} 个视频文件名。")
        print(f"其中 {len(video_files_to_process_ordered)} 个在视频目录中存在，将按照CSV顺序处理。")
        print("--- 待处理的视频列表（来自CSV筛选后，按CSV顺序）---")
        print(video_files_to_process_ordered)
        print("----------------------------------------")
    except Exception as e:
        print(f"读取或解析 {filtered_videos_path} 失败: {e}")
        # 如果读取失败，回退到处理目录中所有视频的逻辑 (此时顺序可能不稳定)
        video_files_to_process_ordered = sorted(list(all_video_files_in_dir)) # 尝试按名称排序作为回退
        print(f"回退：将处理视频目录中的所有视频，共 {len(video_files_to_process_ordered)} 个。")


else:
    print(f"未找到过滤视频列表文件: {filtered_videos_path}，将处理视频目录中的所有视频。")
    # 如果文件不存在，处理目录中所有视频 (此时顺序可能不稳定)
    video_files_to_process_ordered = sorted(list(all_video_files_in_dir)) # 尝试按名称排序作为回退
    print(f"将处理视频目录中的所有视频，共 {len(video_files_to_process_ordered)} 个。")


all_results = []
if os.path.exists(cfg.JSON_OUTPUT_FILE):
    with open(cfg.JSON_OUTPUT_FILE, 'r') as f:
        all_results = json.load(f)
    processed_videos = {item['video_name'] for item in all_results}
    # 仅处理那些在 filtered_videoes.csv 中且尚未处理的视频，保持原有顺序
    video_files_to_process = [f for f in video_files_to_process_ordered if f not in processed_videos]
    print(f"发现已处理 {len(processed_videos)} 个视频，将继续处理剩余的 {len(video_files_to_process)} 个。")
    print("--- 待处理的视频列表（剔除已处理后，按CSV顺序）---")
    print(video_files_to_process)
    print("----------------------------------------")
else:
     # 如果输出文件不存在，则处理从CSV读取的完整列表
     video_files_to_process = video_files_to_process_ordered


uploaded_files = [] # 用于存储本次运行上传的所有文件，以便最后清理

if not video_files_to_process:
    print("没有需要处理的新视频。")
else:
    # 处理过滤后的视频列表
    print(f"将处理 {len(video_files_to_process)} 个视频。")

    for video_name in tqdm(video_files_to_process, desc="处理视频"):
        local_video_path = os.path.join(cfg.VIDEO_INPUT_DIR, video_name)
        print(f"\n--- 正在处理: {video_name} ---")

        try:
            # 1. 上传视频并等待处理
            video_file_handle = upload_video_file(local_video_path)
            uploaded_files.append(video_file_handle) # 记录下来以便清理

            # 2. 运行Gemini流水线
            result = run_gemini_pipeline_for_video(video_file_handle, model)

            if result:
                result['video_name'] = video_name
                all_results.append(result)
                print(f"  成功处理 {video_name} 并获得结果。")
            else:
                print(f"  处理 {video_name} 失败，未获得有效结果。")

        except Exception as e:
            print(f"  处理视频 {video_name} 时发生严重错误: {e}")

        # 3. 定期保存进度
        # 保存逻辑已根据用户需求调整，每处理完一个就保存（为了应对Colab断连），但最终保存会覆盖
        print(f"\n--- 正在保存当前进度 ({len(all_results)} 个视频)... ---")
        # 为了保持原有视频的处理顺序，这里在保存时，需要先将新结果添加到all_results，
        # 然后根据最初的video_files_to_process_ordered列表对all_results进行排序后再保存。
        # 注意：这里假设all_results中的每个字典都有一个'video_name'键
        try:
            # 创建一个字典，key是video_name，value是对应的结果字典
            results_dict = {item['video_name']: item for item in all_results}
            # 按照最初的期望处理顺序，重构all_results列表
            # 确保只包含在 original_video_files_to_process_ordered 中的结果
            # 并且只包含在 results_dict 中已有的结果
            sorted_results = [results_dict[video_name] for video_name in video_files_to_process_ordered if video_name in results_dict]

            with open(cfg.JSON_OUTPUT_FILE, 'w', encoding='utf-8') as f:
                json.dump(sorted_results, f, indent=4, ensure_ascii=False)
        except Exception as e:
             print(f"  保存进度时发生排序或写入错误: {e}. 将直接保存未经排序的当前结果.")
             with open(cfg.JSON_OUTPUT_FILE, 'w', encoding='utf-8') as f:
                json.dump(all_results, f, indent=4, ensure_ascii=False)


    # 4. 最终保存 (虽然上面循环里也在保存，这里再做一次确保)
    print("\n--- 视频处理完毕，正在进行最终保存... ---")
    # 最终保存时也进行排序
    try:
        results_dict = {item['video_name']: item for item in all_results}
        sorted_results = [results_dict[video_name] for video_name in video_files_to_process_ordered if video_name in results_dict]
        with open(cfg.JSON_OUTPUT_FILE, 'w', encoding='utf-8') as f:
            json.dump(sorted_results, f, indent=4, ensure_ascii=False)
    except Exception as e:
        print(f"  最终保存时发生排序或写入错误: {e}. 将直接保存未经排序的最终结果.")
        with open(cfg.JSON_OUTPUT_FILE, 'w', encoding='utf-8') as f:
            json.dump(all_results, f, indent=4, ensure_ascii=False)


    # 5. 清理本次上传的文件
    print("\n--- 正在清理本次上传到Google AI服务器的临时文件... ---")
    for f in uploaded_files:
        try:
            genai.delete_file(f.name)
            print(f"  已删除文件: {f.display_name}")
        except Exception as e:
            print(f"  删除文件 {f.display_name} 失败: {e}")

    print(f"\n流程全部完成！结果已保存在: {cfg.JSON_OUTPUT_FILE}")
# Out:
# 从 /content/drive/MyDrive/data/filtered_videos.csv 读取到 344 个视频文件名。
# 其中 344 个在视频目录中存在，将按照CSV顺序处理。
# --- 待处理的视频列表（来自CSV筛选后，按CSV顺序）---
# ['000003.mp4', '000018.mp4', '000023.mp4', '000031.mp4', '000033.mp4', '000039.mp4', '000048.mp4', '000059.mp4', '000066.mp4', '000074.mp4', '000078.mp4', '000083.mp4', '000087.mp4', '000109.mp4', '000115.mp4', '000130.mp4', '000136.mp4', '000137.mp4', '000142.mp4', '000156.mp4', '000157.mp4', '000159.mp4', '000161.mp4', '000163.mp4', '000166.mp4', '000167.mp4', '000177.mp4', '000179.mp4', '000181.mp4', '000182.mp4', '000185.mp4', '000187.mp4', '000188.mp4', '000190.mp4', '000191.mp4', '000193.mp4', '000198.mp4', '000199.mp4', '000202.mp4', '000206.mp4', '000214.mp4', '000215.mp4', '000220.mp4', '000234.mp4', '000243.mp4', '000244.mp4', '000246.mp4', '000247.mp4', '000250.mp4', '000251.mp4', '000255.mp4', '000256.mp4', '000259.mp4', '000260.mp4', '000264.mp4', '000267.mp4', '000274.mp4', '000276.mp4', '000278.mp4', '000286.mp4', '000300.mp4', '000306.mp4', '000309.mp4', '000325.mp4', '000326.mp4', '000340.mp4', '000343.mp4', '000349.mp4', '000350.mp4', '000352.mp4', '000360.mp4', '000363.mp4', '000365.mp4', '000371.mp4', '000379.mp4', '000391.mp4', '000394.mp4', '000404.mp4', '000407.mp4', '000409.mp4', '000416.mp4', '000425.mp4', '000426.mp4', '000427.mp4', '000428.mp4', '000430.mp4', '000432.mp4', '000435.mp4', '000440.mp4', '000445.mp4', '000462.mp4', '000464.mp4', '000465.mp4', '000474.mp4', '000477.mp4', '000487.mp4', '000491.mp4', '000499.mp4', '000500.mp4', '000501.mp4', '000539.mp4', '000565.mp4', '000572.mp4', '000573.mp4', '000575.mp4', '000578.mp4', '000579.mp4', '000582.mp4', '000588.mp4', '000597.mp4', '000599.mp4', '000601.mp4', '000604.mp4', '000610.mp4', '000614.mp4', '000615.mp4', '000618.mp4', '000629.mp4', '000632.mp4', '000639.mp4', '000655.mp4', '000659.mp4', '000664.mp4', '000667.mp4', '000668.mp4', '000669.mp4', '000678.mp4', '000685.mp4', '000691.mp4', '000692.mp4', '000695.mp4', '000713.mp4', '000715.mp4', '000722.mp4', '000723.mp4', '000726.mp4', '000727.mp4', '000728.mp4', '000729.mp4', '000733.mp4', '000735.mp4', '000738.mp4', '000743.mp4', '000744.mp4', '000748.mp4', '000750.mp4', '000753.mp4', '000760.mp4', '000764.mp4', '000765.mp4', '000770.mp4', '000773.mp4', '000775.mp4', '000783.mp4', '000789.mp4', '000791.mp4', '000792.mp4', '000794.mp4', '000796.mp4', '000797.mp4', '000799.mp4', '000802.mp4', '000803.mp4', '000804.mp4', '000806.mp4', '000807.mp4', '000808.mp4', '000811.mp4', '000815.mp4', '000818.mp4', '000819.mp4', '000820.mp4', '000822.mp4', '000824.mp4', '000830.mp4', '000834.mp4', '000835.mp4', '000836.mp4', '000838.mp4', '000840.mp4', '000843.mp4', '000846.mp4', '000847.mp4', '000850.mp4', '000851.mp4', '000857.mp4', '000859.mp4', '000860.mp4', '000864.mp4', '000867.mp4', '000875.mp4', '000876.mp4', '000877.mp4', '000878.mp4', '000879.mp4', '000887.mp4', '000891.mp4', '000892.mp4', '000897.mp4', '000901.mp4', '000902.mp4', '000908.mp4', '000910.mp4', '000913.mp4', '000914.mp4', '000918.mp4', '000919.mp4', '000924.mp4', '000925.mp4', '000926.mp4', '000927.mp4', '000928.mp4', '000929.mp4', '000938.mp4', '000942.mp4', '000944.mp4', '000946.mp4', '000947.mp4', '000955.mp4', '000967.mp4', '000968.mp4', '000969.mp4', '000971.mp4', '000975.mp4', '000976.mp4', '000980.mp4', '000982.mp4', '000986.mp4', '000988.mp4', '000992.mp4', '000996.mp4', '001000.mp4', '001002.mp4', '001004.mp4', '001017.mp4', '001024.mp4', '001033.mp4', '001034.mp4', '001037.mp4', '001045.mp4', '001049.mp4', '001054.mp4', '001063.mp4', '001064.mp4', '001070.mp4', '001073.mp4', '001074.mp4', '001081.mp4', '001085.mp4', '001092.mp4', '001094.mp4', '001098.mp4', '001103.mp4', '001108.mp4', '001114.mp4', '001126.mp4', '001132.mp4', '001138.mp4', '001141.mp4', '001146.mp4', '001148.mp4', '001157.mp4', '001162.mp4', '001168.mp4', '001169.mp4', '001178.mp4', '001181.mp4', '001184.mp4', '001189.mp4', '001191.mp4', '001207.mp4', '001210.mp4', '001218.mp4', '001219.mp4', '001221.mp4', '001223.mp4', '001228.mp4', '001231.mp4', '001232.mp4', '001237.mp4', '001242.mp4', '001246.mp4', '001247.mp4', '001256.mp4', '001265.mp4', '001275.m ...
# ----------------------------------------
# 发现已处理 242 个视频，将继续处理剩余的 102 个。
# --- 待处理的视频列表（剔除已处理后，按CSV顺序）---
# ['001063.mp4', '001064.mp4', '001070.mp4', '001073.mp4', '001074.mp4', '001081.mp4', '001085.mp4', '001092.mp4', '001094.mp4', '001098.mp4', '001103.mp4', '001108.mp4', '001114.mp4', '001126.mp4', '001132.mp4', '001138.mp4', '001141.mp4', '001146.mp4', '001148.mp4', '001157.mp4', '001162.mp4', '001168.mp4', '001169.mp4', '001178.mp4', '001181.mp4', '001184.mp4', '001189.mp4', '001191.mp4', '001207.mp4', '001210.mp4', '001218.mp4', '001219.mp4', '001221.mp4', '001223.mp4', '001228.mp4', '001231.mp4', '001232.mp4', '001237.mp4', '001242.mp4', '001246.mp4', '001247.mp4', '001256.mp4', '001265.mp4', '001275.mp4', '001276.mp4', '001282.mp4', '001283.mp4', '001284.mp4', '001287.mp4', '001290.mp4', '001293.mp4', '001294.mp4', '001295.mp4', '001300.mp4', '001301.mp4', '001303.mp4', '001308.mp4', '001309.mp4', '001312.mp4', '001314.mp4', '001316.mp4', '001317.mp4', '001321.mp4', '001325.mp4', '001337.mp4', '001340.mp4', '001342.mp4', '001344.mp4', '001345.mp4', '001346.mp4', '001347.mp4', '001349.mp4', '001354.mp4', '001355.mp4', '001359.mp4', '001361.mp4', '001362.mp4', '001363.mp4', '001365.mp4', '001366.mp4', '001367.mp4', '001370.mp4', '001378.mp4', '001379.mp4', '001386.mp4', '001387.mp4', '001390.mp4', '001394.mp4', '001399.mp4', '001406.mp4', '001421.mp4', '001427.mp4', '001428.mp4', '001430.mp4', '001437.mp4', '001452.mp4', '001454.mp4', '001455.mp4', '001475.mp4', '001476.mp4', '001482.mp4', '001484.mp4']
# ----------------------------------------
# 将处理 102 个视频。
# 处理视频:   0%|          | 0/102 [00:00<?, ?it/s]
# --- 正在处理: 001063.mp4 ---
#   正在上传视频: 001063.mp4...
#   视频正在处理中，请稍候...
#   视频 '001063.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001063.mp4 并获得结果。
#
# --- 正在保存当前进度 (243 个视频)... ---
#
# --- 正在处理: 001064.mp4 ---
#   正在上传视频: 001064.mp4...
#   视频正在处理中，请稍候...
#   视频 '001064.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001064.mp4 并获得结果。
#
# --- 正在保存当前进度 (244 个视频)... ---
#
# --- 正在处理: 001070.mp4 ---
#   正在上传视频: 001070.mp4...
#   视频正在处理中，请稍候...
#   视频 '001070.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001070.mp4 并获得结果。
#
# --- 正在保存当前进度 (245 个视频)... ---
#
# --- 正在处理: 001073.mp4 ---
#   正在上传视频: 001073.mp4...
#   视频正在处理中，请稍候...
#   视频 '001073.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001073.mp4 并获得结果。
#
# --- 正在保存当前进度 (246 个视频)... ---
#
# --- 正在处理: 001074.mp4 ---
#   正在上传视频: 001074.mp4...
#   视频正在处理中，请稍候...
#   视频 '001074.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001074.mp4 并获得结果。
#
# --- 正在保存当前进度 (247 个视频)... ---
#
# --- 正在处理: 001081.mp4 ---
#   正在上传视频: 001081.mp4...
#   视频正在处理中，请稍候...
#   视频 '001081.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001081.mp4 并获得结果。
#
# --- 正在保存当前进度 (248 个视频)... ---
#
# --- 正在处理: 001085.mp4 ---
#   正在上传视频: 001085.mp4...
#   视频正在处理中，请稍候...
#   视频 '001085.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001085.mp4 并获得结果。
#
# --- 正在保存当前进度 (249 个视频)... ---
#
# --- 正在处理: 001092.mp4 ---
#   正在上传视频: 001092.mp4...
#   视频正在处理中，请稍候...
#   视频 '001092.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001092.mp4 并获得结果。
#
# --- 正在保存当前进度 (250 个视频)... ---
#
# --- 正在处理: 001094.mp4 ---
#   正在上传视频: 001094.mp4...
#   视频正在处理中，请稍候...
#   视频 '001094.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001094.mp4 并获得结果。
#
# --- 正在保存当前进度 (251 个视频)... ---
#
# --- 正在处理: 001098.mp4 ---
#   正在上传视频: 001098.mp4...
#   视频正在处理中，请稍候...
#   视频 '001098.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001098.mp4 并获得结果。
#
# --- 正在保存当前进度 (252 个视频)... ---
#
# --- 正在处理: 001103.mp4 ---
#   正在上传视频: 001103.mp4...
#   视频正在处理中，请稍候...
#   视频 '001103.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001103.mp4 并获得结果。
#
# --- 正在保存当前进度 (253 个视频)... ---
#
# --- 正在处理: 001108.mp4 ---
#   正在上传视频: 001108.mp4...
#   视频正在处理中，请稍候...
#   视频 '001108.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001108.mp4 并获得结果。
#
# --- 正在保存当前进度 (254 个视频)... ---
#
# --- 正在处理: 001114.mp4 ---
#   正在上传视频: 001114.mp4...
#   视频正在处理中，请稍候...
#   视频 '001114.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001114.mp4 并获得结果。
#
# --- 正在保存当前进度 (255 个视频)... ---
#
# --- 正在处理: 001126.mp4 ---
#   正在上传视频: 001126.mp4...
#   视频正在处理中，请稍候...
#   视频 '001126.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001126.mp4 并获得结果。
#
# --- 正在保存当前进度 (256 个视频)... ---
#
# --- 正在处理: 001132.mp4 ---
#   正在上传视频: 001132.mp4...
#   视频正在处理中，请稍候...
#   视频 '001132.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001132.mp4 并获得结果。
#
# --- 正在保存当前进度 (257 个视频)... ---
#
# --- 正在处理: 001138.mp4 ---
#   正在上传视频: 001138.mp4...
#   视频正在处理中，请稍候...
#   视频 '001138.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001138.mp4 并获得结果。
#
# --- 正在保存当前进度 (258 个视频)... ---
#
# --- 正在处理: 001141.mp4 ---
#   正在上传视频: 001141.mp4...
#   视频正在处理中，请稍候...
#   视频 '001141.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001141.mp4 并获得结果。
#
# --- 正在保存当前进度 (259 个视频)... ---
#
# --- 正在处理: 001146.mp4 ---
#   正在上传视频: 001146.mp4...
#   视频正在处理中，请稍候...
#   视频 '001146.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001146.mp4 并获得结果。
#
# --- 正在保存当前进度 (260 个视频)... ---
#
# --- 正在处理: 001148.mp4 ---
#   正在上传视频: 001148.mp4...
#   视频正在处理中，请稍候...
#   视频 '001148.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001148.mp4 并获得结果。
#
# --- 正在保存当前进度 (261 个视频)... ---
#
# --- 正在处理: 001157.mp4 ---
#   正在上传视频: 001157.mp4...
#   视频正在处理中，请稍候...
#   视频 '001157.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001157.mp4 并获得结果。
#
# --- 正在保存当前进度 (262 个视频)... ---
#
# --- 正在处理: 001162.mp4 ---
#   正在上传视频: 001162.mp4...
#   视频正在处理中，请稍候...
#   视频 '001162.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001162.mp4 并获得结果。
#
# --- 正在保存当前进度 (263 个视频)... ---
#
# --- 正在处理: 001168.mp4 ---
#   正在上传视频: 001168.mp4...
#   视频正在处理中，请稍候...
#   视频 '001168.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001168.mp4 并获得结果。
#
# --- 正在保存当前进度 (264 个视频)... ---
#
# --- 正在处理: 001169.mp4 ---
#   正在上传视频: 001169.mp4...
#   视频正在处理中，请稍候...
#   视频 '001169.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001169.mp4 并获得结果。
#
# --- 正在保存当前进度 (265 个视频)... ---
#
# --- 正在处理: 001178.mp4 ---
#   正在上传视频: 001178.mp4...
#   视频正在处理中，请稍候...
#   视频 '001178.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001178.mp4 并获得结果。
#
# --- 正在保存当前进度 (266 个视频)... ---
#
# --- 正在处理: 001181.mp4 ---
#   正在上传视频: 001181.mp4...
#   视频正在处理中，请稍候...
#   视频 '001181.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001181.mp4 并获得结果。
#
# --- 正在保存当前进度 (267 个视频)... ---
#
# --- 正在处理: 001184.mp4 ---
#   正在上传视频: 001184.mp4...
#   视频正在处理中，请稍候...
#   视频 '001184.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001184.mp4 并获得结果。
#
# --- 正在保存当前进度 (268 个视频)... ---
#
# --- 正在处理: 001189.mp4 ---
#   正在上传视频: 001189.mp4...
#   视频正在处理中，请稍候...
#   视频 '001189.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001189.mp4 并获得结果。
#
# --- 正在保存当前进度 (269 个视频)... ---
#
# --- 正在处理: 001191.mp4 ---
#   正在上传视频: 001191.mp4...
#   视频正在处理中，请稍候...
#   视频 '001191.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001191.mp4 并获得结果。
#
# --- 正在保存当前进度 (270 个视频)... ---
#
# --- 正在处理: 001207.mp4 ---
#   正在上传视频: 001207.mp4...
#   视频正在处理中，请稍候...
#   视频 '001207.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001207.mp4 并获得结果。
#
# --- 正在保存当前进度 (271 个视频)... ---
#
# --- 正在处理: 001210.mp4 ---
#   正在上传视频: 001210.mp4...
#   视频正在处理中，请稍候...
#   视频 '001210.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001210.mp4 并获得结果。
#
# --- 正在保存当前进度 (272 个视频)... ---
#
# --- 正在处理: 001218.mp4 ---
#   正在上传视频: 001218.mp4...
#   视频正在处理中，请稍候...
#   视频 '001218.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001218.mp4 并获得结果。
#
# --- 正在保存当前进度 (273 个视频)... ---
#
# --- 正在处理: 001219.mp4 ---
#   正在上传视频: 001219.mp4...
#   视频正在处理中，请稍候...
#   视频 '001219.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001219.mp4 并获得结果。
#
# --- 正在保存当前进度 (274 个视频)... ---
#
# --- 正在处理: 001221.mp4 ---
#   正在上传视频: 001221.mp4...
#   视频正在处理中，请稍候...
#   视频 '001221.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001221.mp4 并获得结果。
#
# --- 正在保存当前进度 (275 个视频)... ---
#
# --- 正在处理: 001223.mp4 ---
#   正在上传视频: 001223.mp4...
#   视频正在处理中，请稍候...
#   视频 '001223.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001223.mp4 并获得结果。
#
# --- 正在保存当前进度 (276 个视频)... ---
#
# --- 正在处理: 001228.mp4 ---
#   正在上传视频: 001228.mp4...
#   视频正在处理中，请稍候...
#   视频 '001228.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001228.mp4 并获得结果。
#
# --- 正在保存当前进度 (277 个视频)... ---
#
# --- 正在处理: 001231.mp4 ---
#   正在上传视频: 001231.mp4...
#   视频正在处理中，请稍候...
#   视频 '001231.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001231.mp4 并获得结果。
#
# --- 正在保存当前进度 (278 个视频)... ---
#
# --- 正在处理: 001232.mp4 ---
#   正在上传视频: 001232.mp4...
#   视频正在处理中，请稍候...
#   视频 '001232.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001232.mp4 并获得结果。
#
# --- 正在保存当前进度 (279 个视频)... ---
#
# --- 正在处理: 001237.mp4 ---
#   正在上传视频: 001237.mp4...
#   视频正在处理中，请稍候...
#   视频 '001237.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001237.mp4 并获得结果。
#
# --- 正在保存当前进度 (280 个视频)... ---
#
# --- 正在处理: 001242.mp4 ---
#   正在上传视频: 001242.mp4...
#   视频正在处理中，请稍候...
#   视频 '001242.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001242.mp4 并获得结果。
#
# --- 正在保存当前进度 (281 个视频)... ---
#
# --- 正在处理: 001246.mp4 ---
#   正在上传视频: 001246.mp4...
#   视频正在处理中，请稍候...
#   视频 '001246.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001246.mp4 并获得结果。
#
# --- 正在保存当前进度 (282 个视频)... ---
#
# --- 正在处理: 001247.mp4 ---
#   正在上传视频: 001247.mp4...
#   视频正在处理中，请稍候...
#   视频 '001247.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001247.mp4 并获得结果。
#
# --- 正在保存当前进度 (283 个视频)... ---
#
# --- 正在处理: 001256.mp4 ---
#   正在上传视频: 001256.mp4...
#   视频正在处理中，请稍候...
#   视频 '001256.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001256.mp4 并获得结果。
#
# --- 正在保存当前进度 (284 个视频)... ---
#
# --- 正在处理: 001265.mp4 ---
#   正在上传视频: 001265.mp4...
#   视频正在处理中，请稍候...
#   视频 '001265.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001265.mp4 并获得结果。
#
# --- 正在保存当前进度 (285 个视频)... ---
#
# --- 正在处理: 001275.mp4 ---
#   正在上传视频: 001275.mp4...
#   视频正在处理中，请稍候...
#   视频 '001275.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001275.mp4 并获得结果。
#
# --- 正在保存当前进度 (286 个视频)... ---
#
# --- 正在处理: 001276.mp4 ---
#   正在上传视频: 001276.mp4...
#   视频正在处理中，请稍候...
#   视频 '001276.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001276.mp4 并获得结果。
#
# --- 正在保存当前进度 (287 个视频)... ---
#
# --- 正在处理: 001282.mp4 ---
#   正在上传视频: 001282.mp4...
#   视频正在处理中，请稍候...
#   视频 '001282.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001282.mp4 并获得结果。
#
# --- 正在保存当前进度 (288 个视频)... ---
#
# --- 正在处理: 001283.mp4 ---
#   正在上传视频: 001283.mp4...
#   视频正在处理中，请稍候...
#   视频 '001283.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001283.mp4 并获得结果。
#
# --- 正在保存当前进度 (289 个视频)... ---
#
# --- 正在处理: 001284.mp4 ---
#   正在上传视频: 001284.mp4...
#   视频正在处理中，请稍候...
#   视频 '001284.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001284.mp4 并获得结果。
#
# --- 正在保存当前进度 (290 个视频)... ---
#
# --- 正在处理: 001287.mp4 ---
#   正在上传视频: 001287.mp4...
#   视频正在处理中，请稍候...
#   视频 '001287.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001287.mp4 并获得结果。
#
# --- 正在保存当前进度 (291 个视频)... ---
#
# --- 正在处理: 001290.mp4 ---
#   正在上传视频: 001290.mp4...
#   视频正在处理中，请稍候...
#   视频 '001290.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001290.mp4 并获得结果。
#
# --- 正在保存当前进度 (292 个视频)... ---
#
# --- 正在处理: 001293.mp4 ---
#   正在上传视频: 001293.mp4...
#   视频正在处理中，请稍候...
#   视频 '001293.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001293.mp4 并获得结果。
#
# --- 正在保存当前进度 (293 个视频)... ---
#
# --- 正在处理: 001294.mp4 ---
#   正在上传视频: 001294.mp4...
#   视频正在处理中，请稍候...
#   视频 '001294.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001294.mp4 并获得结果。
#
# --- 正在保存当前进度 (294 个视频)... ---
#
# --- 正在处理: 001295.mp4 ---
#   正在上传视频: 001295.mp4...
#   视频正在处理中，请稍候...
#   视频 '001295.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001295.mp4 并获得结果。
#
# --- 正在保存当前进度 (295 个视频)... ---
#
# --- 正在处理: 001300.mp4 ---
#   正在上传视频: 001300.mp4...
#   视频正在处理中，请稍候...
#   视频 '001300.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001300.mp4 并获得结果。
#
# --- 正在保存当前进度 (296 个视频)... ---
#
# --- 正在处理: 001301.mp4 ---
#   正在上传视频: 001301.mp4...
#   视频正在处理中，请稍候...
#   视频 '001301.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001301.mp4 并获得结果。
#
# --- 正在保存当前进度 (297 个视频)... ---
#
# --- 正在处理: 001303.mp4 ---
#   正在上传视频: 001303.mp4...
#   视频正在处理中，请稍候...
#   视频 '001303.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001303.mp4 并获得结果。
#
# --- 正在保存当前进度 (298 个视频)... ---
#
# --- 正在处理: 001308.mp4 ---
#   正在上传视频: 001308.mp4...
#   视频正在处理中，请稍候...
#   视频 '001308.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001308.mp4 并获得结果。
#
# --- 正在保存当前进度 (299 个视频)... ---
#
# --- 正在处理: 001309.mp4 ---
#   正在上传视频: 001309.mp4...
#   视频正在处理中，请稍候...
#   视频 '001309.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001309.mp4 并获得结果。
#
# --- 正在保存当前进度 (300 个视频)... ---
#
# --- 正在处理: 001312.mp4 ---
#   正在上传视频: 001312.mp4...
#   视频正在处理中，请稍候...
#   视频 '001312.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001312.mp4 并获得结果。
#
# --- 正在保存当前进度 (301 个视频)... ---
#
# --- 正在处理: 001314.mp4 ---
#   正在上传视频: 001314.mp4...
#   视频正在处理中，请稍候...
#   视频 '001314.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001314.mp4 并获得结果。
#
# --- 正在保存当前进度 (302 个视频)... ---
#
# --- 正在处理: 001316.mp4 ---
#   正在上传视频: 001316.mp4...
#   视频正在处理中，请稍候...
#   视频 '001316.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001316.mp4 并获得结果。
#
# --- 正在保存当前进度 (303 个视频)... ---
#
# --- 正在处理: 001317.mp4 ---
#   正在上传视频: 001317.mp4...
#   视频正在处理中，请稍候...
#   视频 '001317.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001317.mp4 并获得结果。
#
# --- 正在保存当前进度 (304 个视频)... ---
#
# --- 正在处理: 001321.mp4 ---
#   正在上传视频: 001321.mp4...
#   视频正在处理中，请稍候...
#   视频 '001321.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001321.mp4 并获得结果。
#
# --- 正在保存当前进度 (305 个视频)... ---
#
# --- 正在处理: 001325.mp4 ---
#   正在上传视频: 001325.mp4...
#   视频正在处理中，请稍候...
#   视频 '001325.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001325.mp4 并获得结果。
#
# --- 正在保存当前进度 (306 个视频)... ---
#
# --- 正在处理: 001337.mp4 ---
#   正在上传视频: 001337.mp4...
#   视频正在处理中，请稍候...
#   视频 '001337.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001337.mp4 并获得结果。
#
# --- 正在保存当前进度 (307 个视频)... ---
#
# --- 正在处理: 001340.mp4 ---
#   正在上传视频: 001340.mp4...
#   视频正在处理中，请稍候...
#   视频 '001340.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001340.mp4 并获得结果。
#
# --- 正在保存当前进度 (308 个视频)... ---
#
# --- 正在处理: 001342.mp4 ---
#   正在上传视频: 001342.mp4...
#   视频正在处理中，请稍候...
#   视频 '001342.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001342.mp4 并获得结果。
#
# --- 正在保存当前进度 (309 个视频)... ---
#
# --- 正在处理: 001344.mp4 ---
#   正在上传视频: 001344.mp4...
#   视频正在处理中，请稍候...
#   视频 '001344.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001344.mp4 并获得结果。
#
# --- 正在保存当前进度 (310 个视频)... ---
#
# --- 正在处理: 001345.mp4 ---
#   正在上传视频: 001345.mp4...
#   视频正在处理中，请稍候...
#   视频 '001345.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001345.mp4 并获得结果。
#
# --- 正在保存当前进度 (311 个视频)... ---
#
# --- 正在处理: 001346.mp4 ---
#   正在上传视频: 001346.mp4...
#   视频正在处理中，请稍候...
#   视频 '001346.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001346.mp4 并获得结果。
#
# --- 正在保存当前进度 (312 个视频)... ---
#
# --- 正在处理: 001347.mp4 ---
#   正在上传视频: 001347.mp4...
#   视频正在处理中，请稍候...
#   视频 '001347.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001347.mp4 并获得结果。
#
# --- 正在保存当前进度 (313 个视频)... ---
#
# --- 正在处理: 001349.mp4 ---
#   正在上传视频: 001349.mp4...
#   视频正在处理中，请稍候...
#   视频 '001349.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001349.mp4 并获得结果。
#
# --- 正在保存当前进度 (314 个视频)... ---
#
# --- 正在处理: 001354.mp4 ---
#   正在上传视频: 001354.mp4...
#   视频正在处理中，请稍候...
#   视频 '001354.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001354.mp4 并获得结果。
#
# --- 正在保存当前进度 (315 个视频)... ---
#
# --- 正在处理: 001355.mp4 ---
#   正在上传视频: 001355.mp4...
#   视频正在处理中，请稍候...
#   视频 '001355.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001355.mp4 并获得结果。
#
# --- 正在保存当前进度 (316 个视频)... ---
#
# --- 正在处理: 001359.mp4 ---
#   正在上传视频: 001359.mp4...
#   视频正在处理中，请稍候...
#   视频 '001359.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001359.mp4 并获得结果。
#
# --- 正在保存当前进度 (317 个视频)... ---
#
# --- 正在处理: 001361.mp4 ---
#   正在上传视频: 001361.mp4...
#   视频正在处理中，请稍候...
#   视频 '001361.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001361.mp4 并获得结果。
#
# --- 正在保存当前进度 (318 个视频)... ---
#
# --- 正在处理: 001362.mp4 ---
#   正在上传视频: 001362.mp4...
#   视频正在处理中，请稍候...
#   视频 '001362.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001362.mp4 并获得结果。
#
# --- 正在保存当前进度 (319 个视频)... ---
#
# --- 正在处理: 001363.mp4 ---
#   正在上传视频: 001363.mp4...
#   视频正在处理中，请稍候...
#   视频 '001363.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001363.mp4 并获得结果。
#
# --- 正在保存当前进度 (320 个视频)... ---
#
# --- 正在处理: 001365.mp4 ---
#   正在上传视频: 001365.mp4...
#   视频正在处理中，请稍候...
#   视频 '001365.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001365.mp4 并获得结果。
#
# --- 正在保存当前进度 (321 个视频)... ---
#
# --- 正在处理: 001366.mp4 ---
#   正在上传视频: 001366.mp4...
#   视频正在处理中，请稍候...
#   视频 '001366.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001366.mp4 并获得结果。
#
# --- 正在保存当前进度 (322 个视频)... ---
#
# --- 正在处理: 001367.mp4 ---
#   正在上传视频: 001367.mp4...
#   视频正在处理中，请稍候...
#   视频 '001367.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001367.mp4 并获得结果。
#
# --- 正在保存当前进度 (323 个视频)... ---
#
# --- 正在处理: 001370.mp4 ---
#   正在上传视频: 001370.mp4...
#   视频正在处理中，请稍候...
#   视频 '001370.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001370.mp4 并获得结果。
#
# --- 正在保存当前进度 (324 个视频)... ---
#
# --- 正在处理: 001378.mp4 ---
#   正在上传视频: 001378.mp4...
#   视频正在处理中，请稍候...
#   视频 '001378.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001378.mp4 并获得结果。
#
# --- 正在保存当前进度 (325 个视频)... ---
#
# --- 正在处理: 001379.mp4 ---
#   正在上传视频: 001379.mp4...
#   视频正在处理中，请稍候...
#   视频 '001379.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001379.mp4 并获得结果。
#
# --- 正在保存当前进度 (326 个视频)... ---
#
# --- 正在处理: 001386.mp4 ---
#   正在上传视频: 001386.mp4...
#   视频正在处理中，请稍候...
#   视频 '001386.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001386.mp4 并获得结果。
#
# --- 正在保存当前进度 (327 个视频)... ---
#
# --- 正在处理: 001387.mp4 ---
#   正在上传视频: 001387.mp4...
#   视频正在处理中，请稍候...
#   视频 '001387.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001387.mp4 并获得结果。
#
# --- 正在保存当前进度 (328 个视频)... ---
#
# --- 正在处理: 001390.mp4 ---
#   正在上传视频: 001390.mp4...
#   视频正在处理中，请稍候...
#   视频 '001390.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001390.mp4 并获得结果。
#
# --- 正在保存当前进度 (329 个视频)... ---
#
# --- 正在处理: 001394.mp4 ---
#   正在上传视频: 001394.mp4...
#   视频正在处理中，请稍候...
#   视频 '001394.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001394.mp4 并获得结果。
#
# --- 正在保存当前进度 (330 个视频)... ---
#
# --- 正在处理: 001399.mp4 ---
#   正在上传视频: 001399.mp4...
#   视频正在处理中，请稍候...
#   视频 '001399.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001399.mp4 并获得结果。
#
# --- 正在保存当前进度 (331 个视频)... ---
#
# --- 正在处理: 001406.mp4 ---
#   正在上传视频: 001406.mp4...
#   视频正在处理中，请稍候...
#   视频 '001406.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001406.mp4 并获得结果。
#
# --- 正在保存当前进度 (332 个视频)... ---
#
# --- 正在处理: 001421.mp4 ---
#   正在上传视频: 001421.mp4...
#   视频正在处理中，请稍候...
#   视频 '001421.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001421.mp4 并获得结果。
#
# --- 正在保存当前进度 (333 个视频)... ---
#
# --- 正在处理: 001427.mp4 ---
#   正在上传视频: 001427.mp4...
#   视频正在处理中，请稍候...
#   视频 '001427.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001427.mp4 并获得结果。
#
# --- 正在保存当前进度 (334 个视频)... ---
#
# --- 正在处理: 001428.mp4 ---
#   正在上传视频: 001428.mp4...
#   视频正在处理中，请稍候...
#   视频 '001428.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001428.mp4 并获得结果。
#
# --- 正在保存当前进度 (335 个视频)... ---
#
# --- 正在处理: 001430.mp4 ---
#   正在上传视频: 001430.mp4...
#   视频正在处理中，请稍候...
#   视频 '001430.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001430.mp4 并获得结果。
#
# --- 正在保存当前进度 (336 个视频)... ---
#
# --- 正在处理: 001437.mp4 ---
#   正在上传视频: 001437.mp4...
#   视频正在处理中，请稍候...
#   视频 '001437.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001437.mp4 并获得结果。
#
# --- 正在保存当前进度 (337 个视频)... ---
#
# --- 正在处理: 001452.mp4 ---
#   正在上传视频: 001452.mp4...
#   视频正在处理中，请稍候...
#   视频 '001452.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001452.mp4 并获得结果。
#
# --- 正在保存当前进度 (338 个视频)... ---
#
# --- 正在处理: 001454.mp4 ---
#   正在上传视频: 001454.mp4...
#   视频正在处理中，请稍候...
#   视频 '001454.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001454.mp4 并获得结果。
#
# --- 正在保存当前进度 (339 个视频)... ---
#
# --- 正在处理: 001455.mp4 ---
#   正在上传视频: 001455.mp4...
#   视频正在处理中，请稍候...
#   视频 '001455.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001455.mp4 并获得结果。
#
# --- 正在保存当前进度 (340 个视频)... ---
#
# --- 正在处理: 001475.mp4 ---
#   正在上传视频: 001475.mp4...
#   视频正在处理中，请稍候...
#   视频 '001475.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001475.mp4 并获得结果。
#
# --- 正在保存当前进度 (341 个视频)... ---
#
# --- 正在处理: 001476.mp4 ---
#   正在上传视频: 001476.mp4...
#   视频正在处理中，请稍候...
#   视频 '001476.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001476.mp4 并获得结果。
#
# --- 正在保存当前进度 (342 个视频)... ---
#
# --- 正在处理: 001482.mp4 ---
#   正在上传视频: 001482.mp4...
#   视频正在处理中，请稍候...
#   视频 '001482.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001482.mp4 并获得结果。
#
# --- 正在保存当前进度 (343 个视频)... ---
#
# --- 正在处理: 001484.mp4 ---
#   正在上传视频: 001484.mp4...
#   视频正在处理中，请稍候...
#   视频 '001484.mp4' 上传并处理成功！
#     -> 阶段1: 正在进行场景分析...
#     -> 阶段2: 正在生成VQA...
#   成功处理 001484.mp4 并获得结果。
#
# --- 正在保存当前进度 (344 个视频)... ---
#
# --- 视频处理完毕，正在进行最终保存... ---
#
# --- 正在清理本次上传到Google AI服务器的临时文件... ---
#   已删除文件: 001063.mp4
#   已删除文件: 001064.mp4
#   已删除文件: 001070.mp4
#   已删除文件: 001073.mp4
#   已删除文件: 001074.mp4
#   已删除文件: 001081.mp4
#   已删除文件: 001085.mp4
#   已删除文件: 001092.mp4
#   已删除文件: 001094.mp4
#   已删除文件: 001098.mp4
#   已删除文件: 001103.mp4
#   已删除文件: 001108.mp4
#   已删除文件: 001114.mp4
#   已删除文件: 001126.mp4
#   已删除文件: 001132.mp4
#   已删除文件: 001138.mp4
#   已删除文件: 001141.mp4
#   已删除文件: 001146.mp4
#   已删除文件: 001148.mp4
#   已删除文件: 001157.mp4
#   已删除文件: 001162.mp4
#   已删除文件: 001168.mp4
#   已删除文件: 001169.mp4
#   已删除文件: 001178.mp4
#   已删除文件: 001181.mp4
#   已删除文件: 001184.mp4
#   已删除文件: 001189.mp4
#   已删除文件: 001191.mp4
#   已删除文件: 001207.mp4
#   已删除文件: 001210.mp4
#   已删除文件: 001218.mp4
#   已删除文件: 001219.mp4
#   已删除文件: 001221.mp4
#   已删除文件: 001223.mp4
#   已删除文件: 001228.mp4
#   已删除文件: 001231.mp4
#   已删除文件: 001232.mp4
#   已删除文件: 001237.mp4
#   已删除文件: 001242.mp4
#   已删除文件: 001246.mp4
#   已删除文件: 001247.mp4
#   已删除文件: 001256.mp4
#   已删除文件: 001265.mp4
#   已删除文件: 001275.mp4
#   已删除文件: 001276.mp4
#   已删除文件: 001282.mp4
#   已删除文件: 001283.mp4
#   已删除文件: 001284.mp4
#   已删除文件: 001287.mp4
#   已删除文件: 001290.mp4
#   已删除文件: 001293.mp4
#   已删除文件: 001294.mp4
#   已删除文件: 001295.mp4
#   已删除文件: 001300.mp4
#   已删除文件: 001301.mp4
#   已删除文件: 001303.mp4
#   已删除文件: 001308.mp4
#   已删除文件: 001309.mp4
#   已删除文件: 001312.mp4
#   已删除文件: 001314.mp4
#   已删除文件: 001316.mp4
#   已删除文件: 001317.mp4
#   已删除文件: 001321.mp4
#   已删除文件: 001325.mp4
#   已删除文件: 001337.mp4
#   已删除文件: 001340.mp4
#   已删除文件: 001342.mp4
#   已删除文件: 001344.mp4
#   已删除文件: 001345.mp4
#   已删除文件: 001346.mp4
#   已删除文件: 001347.mp4
#   已删除文件: 001349.mp4
#   已删除文件: 001354.mp4
#   已删除文件: 001355.mp4
#   已删除文件: 001359.mp4
#   已删除文件: 001361.mp4
#   已删除文件: 001362.mp4
#   已删除文件: 001363.mp4
#   已删除文件: 001365.mp4
#   已删除文件: 001366.mp4
#   已删除文件: 001367.mp4
#   已删除文件: 001370.mp4
#   已删除文件: 001378.mp4
#   已删除文件: 001379.mp4
#   已删除文件: 001386.mp4
#   已删除文件: 001387.mp4
#   已删除文件: 001390.mp4
#   已删除文件: 001394.mp4
#   已删除文件: 001399.mp4
#   已删除文件: 001406.mp4
#   已删除文件: 001421.mp4
#   已删除文件: 001427.mp4
#   已删除文件: 001428.mp4
#   已删除文件: 001430.mp4
#   已删除文件: 001437.mp4
#   已删除文件: 001452.mp4
#   已删除文件: 001454.mp4
#   已删除文件: 001455.mp4
#   已删除文件: 001475.mp4
#   已删除文件: 001476.mp4
#   已删除文件: 001482.mp4
#   已删除文件: 001484.mp4
#
# 流程全部完成！结果已保存在: /content/drive/MyDrive/data/VQA_outputs/generated_vqa.json
